# %%
cd /content/drive/MyDrive/Corpus NMT Translasi
# Out:
# /content/drive/MyDrive/Corpus NMT Translasi

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Corpus NMT Translasi

# %%
import tensorflow as tf

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.model_selection import train_test_split
import pandas as pd
import unicodedata
import re
import numpy as np
import os
import io
import time
from string import digits

# %%
path_to_file = "Corpus1000Kalimat.txt"

# %%
#Read the data
lines_raw= pd.read_table(path_to_file,names=['target', 'input',])
lines_raw.sample(5)
# Out:
#                                                 target  \
# 108  waste steel factories, paint factories, and ph...
# 208  Incidentally, the owner of the tire patch is a...
# 444  Sorry to tell you this, Saly has been working ...
# 593  The length of the resultant vector can be meas...
# 939  Social symptoms can be a sign that there are v...
#
#                                                  input
# 108  limbah pabrik baja, pabrik cat, dan pabrik far...
# 208  Kebetulan pemilik tambal ban itu sudah kenal d...
# 444  Maaf untuk kabarkan hal ini, Saly beberapa tah...
# 593  Panjang resultan vektor dapat diukur menggunak...
# 939  Gejala sosial bisa menjadi penanda bahwa ada n...

# %%
# Converts the unicode file to ascii
def unicode_to_ascii(s):
  return ''.join(c for c in unicodedata.normalize('NFD', s)
      if unicodedata.category(c) != 'Mn')


def preprocess_sentence(w):
  w = unicode_to_ascii(w.lower().strip())

  # creating a space between a word and the punctuation following it
  # eg: "he is a boy." => "he is a boy ."
  # Reference:- https://stackoverflow.com/questions/3645931/python-padding-punctuation-with-white-spaces-keeping-punctuation
  w = re.sub(r"([?.!,¿])", r" \1 ", w)
  w = re.sub(r'[" "]+', " ", w)

  # replacing everything with space except (a-z, A-Z, ".", "?", "!", ",")
  w = re.sub(r"[^a-zA-Z?.!,¿]+", " ", w)

  w = w.strip()

  # adding a start and an end token to the sentence
  # so that the model know when to start and stop predicting.
  w = '<start> ' + w + ' <end>'
  return w

# %%
en_sentence = u"Aren't you still living in Boston?"
id_sentence = u"Bukannya kamu masih tinggal di Boston?"
print(preprocess_sentence(en_sentence))
print(preprocess_sentence(id_sentence).encode('utf-8'))
# Out:
# <start> aren t you still living in boston ? <end>
# b'<start> bukannya kamu masih tinggal di boston ? <end>'

# %%
# 1. Remove the accents
# 2. Clean the sentences
# 3. Return word pairs in the format: [ENGLISH, INDONESIA]
def create_dataset(path, num_examples):
  lines = io.open(path, encoding='UTF-8').read().strip().split('\n')

  word_pairs = [[preprocess_sentence(w) for w in l.split('\t')[:2]]  for l in lines[:num_examples]]

  return zip(*word_pairs)

# %%
en, id = create_dataset(path_to_file, None)
print(en[-1])
print(id[-1])
# Out:
# <start> then malin is provided with rice wrapped in banana leaves as much as seven packs <end>
# <start> kemudian malin dibekali dengan nasi berbungkus daun pisang sebanyak tujuh bungkus <end>

# %%
def tokenize(lang):
  lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(
      filters='')
  lang_tokenizer.fit_on_texts(lang)

  tensor = lang_tokenizer.texts_to_sequences(lang)

  tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor,
                                                         padding='post')

  return tensor, lang_tokenizer

# %%
def load_dataset(path, num_examples=None):
  # creating cleaned input, output pairs
  targ_lang, inp_lang = create_dataset(path, num_examples)

  input_tensor, inp_lang_tokenizer = tokenize(inp_lang)
  target_tensor, targ_lang_tokenizer = tokenize(targ_lang)

  return input_tensor, target_tensor, inp_lang_tokenizer, targ_lang_tokenizer

# %%
# Try experimenting with the size of that dataset
# karena data korpus kita Tujuh Ribu Lebih kita genapkan saja menjadi 7000 data saja yang di proses
num_examples = 1010
input_tensor, target_tensor, inp_lang, targ_lang = load_dataset(path_to_file, num_examples)

# Calculate max_length of the target tensors
max_length_targ, max_length_inp = target_tensor.shape[1], input_tensor.shape[1]

# %%
# Creating training and validation sets using an 80-20 split
# kita akan membuat data yang diproses untuk dilatih 80% dan 20% untuk di validasi, tetapi data validasi ini selanjutnya tidak diproses
input_tensor_train, input_tensor_val, target_tensor_train, target_tensor_val = train_test_split(input_tensor, target_tensor, test_size=0.2)

# Show length
print(len(input_tensor_train), len(target_tensor_train), len(input_tensor_val), len(target_tensor_val))
# Out:
# 808 808 202 202

# %%
def convert(lang, tensor):
  for t in tensor:
    if t!=0:
      print ("%d ----> %s" % (t, lang.index_word[t]))

# %%
print ("Input Language; index to word mapping")
convert(inp_lang, input_tensor_train[0])
print ()
print ("Target Language; index to word mapping")
convert(targ_lang, target_tensor_train[0])
# Out:
# Input Language; index to word mapping
# 1 ----> <start>
# 72 ----> semua
# 25 ----> orang
# 1095 ----> terdiam
# 494 ----> mendengar
# 2968 ----> penjelasan
# 10 ----> dari
# 1522 ----> kak
# 972 ----> rifki
# 6 ----> .
# 2969 ----> seketika
# 59 ----> mereka
# 149 ----> merasa
# 117 ----> telah
# 301 ----> melakukan
# 137 ----> hal
# 708 ----> bodoh
# 2 ----> <end>
#
# Target Language; index to word mapping
# 2 ----> <start>
# 298 ----> everyone
# 17 ----> was
# 1101 ----> silent
# 7 ----> to
# 832 ----> hear
# 1 ----> the
# 2873 ----> explanation
# 20 ----> from
# 1508 ----> kak
# 965 ----> rifki
# 8 ----> .
# 2874 ----> instantly
# 62 ----> they
# 488 ----> felt
# 62 ----> they
# 83 ----> had
# 248 ----> done
# 426 ----> something
# 2875 ----> stupid
# 3 ----> <end>

# %%
BUFFER_SIZE = len(input_tensor_train)
BATCH_SIZE = 64
steps_per_epoch = len(input_tensor_train)//BATCH_SIZE
embedding_dim = 256
units = 1024
vocab_inp_size = len(inp_lang.word_index)+1
vocab_tar_size = len(targ_lang.word_index)+1

dataset = tf.data.Dataset.from_tensor_slices((input_tensor_train, target_tensor_train)).shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

# %%
example_input_batch, example_target_batch = next(iter(dataset))
example_input_batch.shape, example_target_batch.shape
# Out:
# (TensorShape([64, 38]), TensorShape([64, 53]))

# %%
class Encoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
    super(Encoder, self).__init__()
    self.batch_sz = batch_sz
    self.enc_units = enc_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.enc_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')

  def call(self, x, hidden):
    x = self.embedding(x)
    output, state = self.gru(x, initial_state = hidden)
    return output, state

  def initialize_hidden_state(self):
    return tf.zeros((self.batch_sz, self.enc_units))

# %%
encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)
# sample input
sample_hidden = encoder.initialize_hidden_state()
sample_output, sample_hidden = encoder(example_input_batch, sample_hidden)
print ('Encoder output shape: (batch size, sequence length, units) {}'.format(sample_output.shape))
print ('Encoder Hidden state shape: (batch size, units) {}'.format(sample_hidden.shape))
# Out:
# Encoder output shape: (batch size, sequence length, units) (64, 38, 1024)
# Encoder Hidden state shape: (batch size, units) (64, 1024)

# %%
class BahdanauAttention(tf.keras.layers.Layer):
  def __init__(self, units):
    super(BahdanauAttention, self).__init__()
    self.W1 = tf.keras.layers.Dense(units)
    self.W2 = tf.keras.layers.Dense(units)
    self.V = tf.keras.layers.Dense(1)

  def call(self, query, values):
    # query hidden state shape == (batch_size, hidden size)
    # query_with_time_axis shape == (batch_size, 1, hidden size)
    # values shape == (batch_size, max_len, hidden size)
    # we are doing this to broadcast addition along the time axis to calculate the score
    query_with_time_axis = tf.expand_dims(query, 1)

    # score shape == (batch_size, max_length, 1)
    # we get 1 at the last axis because we are applying score to self.V
    # the shape of the tensor before applying self.V is (batch_size, max_length, units)
    score = self.V(tf.nn.tanh(
        self.W1(query_with_time_axis) + self.W2(values)))

    # attention_weights shape == (batch_size, max_length, 1)
    attention_weights = tf.nn.softmax(score, axis=1)

    # context_vector shape after sum == (batch_size, hidden_size)
    context_vector = attention_weights * values
    context_vector = tf.reduce_sum(context_vector, axis=1)

    return context_vector, attention_weights

# %%
attention_layer = BahdanauAttention(10)
attention_result, attention_weights = attention_layer(sample_hidden, sample_output)

print("Attention result shape: (batch size, units) {}".format(attention_result.shape))
print("Attention weights shape: (batch_size, sequence_length, 1) {}".format(attention_weights.shape))
# Out:
# Attention result shape: (batch size, units) (64, 1024)
# Attention weights shape: (batch_size, sequence_length, 1) (64, 38, 1)

# %%
class Decoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
    super(Decoder, self).__init__()
    self.batch_sz = batch_sz
    self.dec_units = dec_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.dec_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.fc = tf.keras.layers.Dense(vocab_size)

    # used for attention
    self.attention = BahdanauAttention(self.dec_units)

  def call(self, x, hidden, enc_output):
    # enc_output shape == (batch_size, max_length, hidden_size)
    context_vector, attention_weights = self.attention(hidden, enc_output)

    # x shape after passing through embedding == (batch_size, 1, embedding_dim)
    x = self.embedding(x)

    # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)
    x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

    # passing the concatenated vector to the GRU
    output, state = self.gru(x)

    # output shape == (batch_size * 1, hidden_size)
    output = tf.reshape(output, (-1, output.shape[2]))

    # output shape == (batch_size, vocab)
    x = self.fc(output)

    return x, state, attention_weights

# %%
decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE)

sample_decoder_output, _, _ = decoder(tf.random.uniform((BATCH_SIZE, 1)), 
                                      sample_hidden, sample_output)

print ('Decoder output shape: (batch_size, vocab size) {}'.format(sample_decoder_output.shape))
# Out:
# Decoder output shape: (batch_size, vocab size) (64, 3106)

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_mean(loss_)

# %%
checkpoint_dir = './training_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer, 
                                 encoder=encoder,
                                 decoder=decoder)

# %%
@tf.function
def train_step(inp, targ, enc_hidden):
  loss = 0

  with tf.GradientTape() as tape:
    enc_output, enc_hidden = encoder(inp, enc_hidden)

    dec_hidden = enc_hidden

    dec_input = tf.expand_dims([targ_lang.word_index['<start>']] * BATCH_SIZE, 1)

    # Teacher forcing - feeding the target as the next input
    for t in range(1, targ.shape[1]):
      # passing enc_output to the decoder
      predictions, dec_hidden, _ = decoder(dec_input, dec_hidden, enc_output)

      loss += loss_function(targ[:, t], predictions)

      # using teacher forcing
      dec_input = tf.expand_dims(targ[:, t], 1)

  batch_loss = (loss / int(targ.shape[1]))

  variables = encoder.trainable_variables + decoder.trainable_variables

  gradients = tape.gradient(loss, variables)

  optimizer.apply_gradients(zip(gradients, variables))

  return batch_loss

# %%
EPOCHS = 100

for epoch in range(EPOCHS):
  start = time.time()

  enc_hidden = encoder.initialize_hidden_state()
  total_loss = 0

  for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
    batch_loss = train_step(inp, targ, enc_hidden)
    total_loss += batch_loss

    if batch % 100 == 0:
      print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
                                                   batch,
                                                   batch_loss.numpy()))

  # saving (checkpoint) the model every 2 epochs
  if (epoch + 1) % 2 == 0:
    checkpoint.save(file_prefix = checkpoint_prefix)

  print('Epoch {} Loss {:.4f}'.format(epoch + 1,
                                      total_loss / steps_per_epoch))
  print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 2.7452
# Epoch 1 Loss 2.4283
# Time taken for 1 epoch 94.16095685958862 sec
#
# Epoch 2 Batch 0 Loss 2.3642
# Epoch 2 Loss 2.1576
# Time taken for 1 epoch 13.772047281265259 sec
#
# Epoch 3 Batch 0 Loss 2.0472
# Epoch 3 Loss 2.0922
# Time taken for 1 epoch 12.679525136947632 sec
#
# Epoch 4 Batch 0 Loss 2.0683
# Epoch 4 Loss 2.0475
# Time taken for 1 epoch 13.360315561294556 sec
#
# Epoch 5 Batch 0 Loss 1.9295
# Epoch 5 Loss 2.0006
# Time taken for 1 epoch 12.665422201156616 sec
#
# Epoch 6 Batch 0 Loss 1.9530
# Epoch 6 Loss 1.9331
# Time taken for 1 epoch 13.3408522605896 sec
#
# Epoch 7 Batch 0 Loss 1.8748
# Epoch 7 Loss 1.8647
# Time taken for 1 epoch 12.61400318145752 sec
#
# Epoch 8 Batch 0 Loss 1.7925
# Epoch 8 Loss 1.8072
# Time taken for 1 epoch 13.723565101623535 sec
#
# Epoch 9 Batch 0 Loss 1.7307
# Epoch 9 Loss 1.7420
# Time taken for 1 epoch 12.611334800720215 sec
#
# Epoch 10 Batch 0 Loss 1.6793
# Epoch 10 Loss 1.6832
# Time taken for 1 epoch 13.34770655632019 sec
#
# Epoch 11 Batch 0 Loss 1.6473
# Epoch 11 Loss 1.6241
# Time taken for 1 epoch 12.659698009490967 sec
#
# Epoch 12 Batch 0 Loss 1.5959
# Epoch 12 Loss 1.5793
# Time taken for 1 epoch 13.413075923919678 sec
#
# Epoch 13 Batch 0 Loss 1.4382
# Epoch 13 Loss 1.5138
# Time taken for 1 epoch 12.605630874633789 sec
#
# Epoch 14 Batch 0 Loss 1.3711
# Epoch 14 Loss 1.4652
# Time taken for 1 epoch 13.620234489440918 sec
#
# Epoch 15 Batch 0 Loss 1.4400
# Epoch 15 Loss 1.4071
# Time taken for 1 epoch 12.639030933380127 sec
#
# Epoch 16 Batch 0 Loss 1.3279
# Epoch 16 Loss 1.3497
# Time taken for 1 epoch 13.475127458572388 sec
#
# Epoch 17 Batch 0 Loss 1.2649
# Epoch 17 Loss 1.2946
# Time taken for 1 epoch 12.591796875 sec
#
# Epoch 18 Batch 0 Loss 1.2195
# Epoch 18 Loss 1.2460
# Time taken for 1 epoch 21.545056343078613 sec
#
# Epoch 19 Batch 0 Loss 1.1998
# Epoch 19 Loss 1.2022
# Time taken for 1 epoch 12.701406478881836 sec
#
# Epoch 20 Batch 0 Loss 1.1351
# Epoch 20 Loss 1.1450
# Time taken for 1 epoch 13.348220825195312 sec
#
# Epoch 21 Batch 0 Loss 1.0169
# Epoch 21 Loss 1.0904
# Time taken for 1 epoch 12.60569715499878 sec
#
# Epoch 22 Batch 0 Loss 1.0486
# Epoch 22 Loss 1.0408
# Time taken for 1 epoch 13.345375299453735 sec
#
# Epoch 23 Batch 0 Loss 0.9410
# Epoch 23 Loss 0.9853
# Time taken for 1 epoch 12.63916540145874 sec
#
# Epoch 24 Batch 0 Loss 0.9463
# Epoch 24 Loss 0.9383
# Time taken for 1 epoch 13.590711832046509 sec
#
# Epoch 25 Batch 0 Loss 0.8466
# Epoch 25 Loss 0.8815
# Time taken for 1 epoch 12.581982374191284 sec
#
# Epoch 26 Batch 0 Loss 0.7871
# Epoch 26 Loss 0.8313
# Time taken for 1 epoch 13.570339679718018 sec
#
# Epoch 27 Batch 0 Loss 0.8085
# Epoch 27 Loss 0.7827
# Time taken for 1 epoch 12.622978687286377 sec
#
# Epoch 28 Batch 0 Loss 0.6942
# Epoch 28 Loss 0.7427
# Time taken for 1 epoch 14.009525060653687 sec
#
# Epoch 29 Batch 0 Loss 0.7341
# Epoch 29 Loss 0.6969
# Time taken for 1 epoch 12.585302591323853 sec
#
# Epoch 30 Batch 0 Loss 0.6429
# Epoch 30 Loss 0.6563
# Time taken for 1 epoch 13.62217116355896 sec
#
# Epoch 31 Batch 0 Loss 0.5279
# Epoch 31 Loss 0.6165
# Time taken for 1 epoch 12.616164445877075 sec
#
# Epoch 32 Batch 0 Loss 0.5735
# Epoch 32 Loss 0.5835
# Time taken for 1 epoch 13.81706190109253 sec
#
# Epoch 33 Batch 0 Loss 0.5129
# Epoch 33 Loss 0.5485
# Time taken for 1 epoch 12.5597984790802 sec
#
# Epoch 34 Batch 0 Loss 0.5149
# Epoch 34 Loss 0.5130
# Time taken for 1 epoch 13.939486742019653 sec
#
# Epoch 35 Batch 0 Loss 0.5088
# Epoch 35 Loss 0.4773
# Time taken for 1 epoch 12.594122886657715 sec
#
# Epoch 36 Batch 0 Loss 0.4276
# Epoch 36 Loss 0.4487
# Time taken for 1 epoch 14.317241430282593 sec
#
# Epoch 37 Batch 0 Loss 0.3733
# Epoch 37 Loss 0.4173
# Time taken for 1 epoch 12.587117195129395 sec
#
# Epoch 38 Batch 0 Loss 0.3356
# Epoch 38 Loss 0.3872
# Time taken for 1 epoch 14.102337121963501 sec
#
# Epoch 39 Batch 0 Loss 0.3144
# Epoch 39 Loss 0.3566
# Time taken for 1 epoch 12.542001724243164 sec
#
# Epoch 40 Batch 0 Loss 0.3164
# Epoch 40 Loss 0.3314
# Time taken for 1 epoch 13.663394212722778 sec
#
# Epoch 41 Batch 0 Loss 0.3145
# Epoch 41 Loss 0.3066
# Time taken for 1 epoch 12.584487915039062 sec
#
# Epoch 42 Batch 0 Loss 0.2453
# Epoch 42 Loss 0.2828
# Time taken for 1 epoch 13.753781795501709 sec
#
# Epoch 43 Batch 0 Loss 0.2685
# Epoch 43 Loss 0.2606
# Time taken for 1 epoch 12.55885124206543 sec
#
# Epoch 44 Batch 0 Loss 0.2362
# Epoch 44 Loss 0.2378
# Time taken for 1 epoch 13.665770530700684 sec
#
# Epoch 45 Batch 0 Loss 0.2161
# Epoch 45 Loss 0.2166
# Time taken for 1 epoch 12.632805585861206 sec
#
# Epoch 46 Batch 0 Loss 0.2135
# Epoch 46 Loss 0.2070
# Time taken for 1 epoch 13.620089292526245 sec
#
# Epoch 47 Batch 0 Loss 0.2037
# Epoch 47 Loss 0.1889
# Time taken for 1 epoch 12.563311338424683 sec
#
# Epoch 48 Batch 0 Loss 0.1659
# Epoch 48 Loss 0.1708
# Time taken for 1 epoch 13.696751117706299 sec
#
# Epoch 49 Batch 0 Loss 0.1540
# Epoch 49 Loss 0.1542
# Time taken for 1 epoch 12.590577602386475 sec
#
# Epoch 50 Batch 0 Loss 0.1228
# Epoch 50 Loss 0.1367
# Time taken for 1 epoch 13.672644853591919 sec
#
# Epoch 51 Batch 0 Loss 0.1326
# Epoch 51 Loss 0.1261
# Time taken for 1 epoch 12.602241277694702 sec
#
# Epoch 52 Batch 0 Loss 0.1201
# Epoch 52 Loss 0.1150
# Time taken for 1 epoch 13.687478065490723 sec
#
# Epoch 53 Batch 0 Loss 0.1016
# Epoch 53 Loss 0.1073
# Time taken for 1 epoch 12.607587814331055 sec
#
# Epoch 54 Batch 0 Loss 0.1046
# Epoch 54 Loss 0.0959
# Time taken for 1 epoch 13.765552282333374 sec
#
# Epoch 55 Batch 0 Loss 0.0763
# Epoch 55 Loss 0.0899
# Time taken for 1 epoch 12.561335802078247 sec
#
# Epoch 56 Batch 0 Loss 0.0700
# Epoch 56 Loss 0.0820
# Time taken for 1 epoch 13.778517484664917 sec
#
# Epoch 57 Batch 0 Loss 0.0736
# Epoch 57 Loss 0.0756
# Time taken for 1 epoch 12.555519580841064 sec
#
# Epoch 58 Batch 0 Loss 0.0708
# Epoch 58 Loss 0.0687
# Time taken for 1 epoch 13.676282167434692 sec
#
# Epoch 59 Batch 0 Loss 0.0638
# Epoch 59 Loss 0.0636
# Time taken for 1 epoch 12.60110855102539 sec
#
# Epoch 60 Batch 0 Loss 0.0606
# Epoch 60 Loss 0.0611
# Time taken for 1 epoch 13.651911973953247 sec
#
# Epoch 61 Batch 0 Loss 0.0718
# Epoch 61 Loss 0.0570
# Time taken for 1 epoch 12.558908462524414 sec
#
# Epoch 62 Batch 0 Loss 0.0448
# Epoch 62 Loss 0.0541
# Time taken for 1 epoch 13.95126223564148 sec
#
# Epoch 63 Batch 0 Loss 0.0541
# Epoch 63 Loss 0.0507
# Time taken for 1 epoch 12.54747223854065 sec
#
# Epoch 64 Batch 0 Loss 0.0471
# Epoch 64 Loss 0.0474
# Time taken for 1 epoch 13.666516542434692 sec
#
# Epoch 65 Batch 0 Loss 0.0435
# Epoch 65 Loss 0.0444
# Time taken for 1 epoch 12.609130382537842 sec
#
# Epoch 66 Batch 0 Loss 0.0440
# Epoch 66 Loss 0.0417
# Time taken for 1 epoch 13.699235200881958 sec
#
# Epoch 67 Batch 0 Loss 0.0393
# Epoch 67 Loss 0.0390
# Time taken for 1 epoch 12.503355979919434 sec
#
# Epoch 68 Batch 0 Loss 0.0368
# Epoch 68 Loss 0.0356
# Time taken for 1 epoch 13.629769802093506 sec
#
# Epoch 69 Batch 0 Loss 0.0282
# Epoch 69 Loss 0.0335
# Time taken for 1 epoch 12.601024866104126 sec
#
# Epoch 70 Batch 0 Loss 0.0380
# Epoch 70 Loss 0.0314
# Time taken for 1 epoch 13.613172769546509 sec
#
# Epoch 71 Batch 0 Loss 0.0242
# Epoch 71 Loss 0.0303
# Time taken for 1 epoch 12.598651885986328 sec
#
# Epoch 72 Batch 0 Loss 0.0282
# Epoch 72 Loss 0.0314
# Time taken for 1 epoch 13.644715785980225 sec
#
# Epoch 73 Batch 0 Loss 0.0199
# Epoch 73 Loss 0.0303
# Time taken for 1 epoch 12.620452642440796 sec
#
# Epoch 74 Batch 0 Loss 0.0234
# Epoch 74 Loss 0.0351
# Time taken for 1 epoch 13.657655239105225 sec
#
# Epoch 75 Batch 0 Loss 0.0503
# Epoch 75 Loss 0.0542
# Time taken for 1 epoch 12.558627843856812 sec
#
# Epoch 76 Batch 0 Loss 0.0520
# Epoch 76 Loss 0.0630
# Time taken for 1 epoch 13.996333599090576 sec
#
# Epoch 77 Batch 0 Loss 0.0546
# Epoch 77 Loss 0.0608
# Time taken for 1 epoch 12.573757410049438 sec
#
# Epoch 78 Batch 0 Loss 0.0542
# Epoch 78 Loss 0.0542
# Time taken for 1 epoch 13.58366084098816 sec
#
# Epoch 79 Batch 0 Loss 0.0517
# Epoch 79 Loss 0.0486
# Time taken for 1 epoch 12.563892602920532 sec
#
# Epoch 80 Batch 0 Loss 0.0346
# Epoch 80 Loss 0.0410
# Time taken for 1 epoch 13.743185997009277 sec
#
# Epoch 81 Batch 0 Loss 0.0280
# Epoch 81 Loss 0.0365
# Time taken for 1 epoch 12.513753890991211 sec
#
# Epoch 82 Batch 0 Loss 0.0435
# Epoch 82 Loss 0.0316
# Time taken for 1 epoch 13.73172903060913 sec
#
# Epoch 83 Batch 0 Loss 0.0276
# Epoch 83 Loss 0.0274
# Time taken for 1 epoch 12.587515354156494 sec
#
# Epoch 84 Batch 0 Loss 0.0243
# Epoch 84 Loss 0.0230
# Time taken for 1 epoch 13.526893377304077 sec
#
# Epoch 85 Batch 0 Loss 0.0274
# Epoch 85 Loss 0.0200
# Time taken for 1 epoch 12.566097736358643 sec
#
# Epoch 86 Batch 0 Loss 0.0179
# Epoch 86 Loss 0.0164
# Time taken for 1 epoch 13.889771938323975 sec
#
# Epoch 87 Batch 0 Loss 0.0155
# Epoch 87 Loss 0.0153
# Time taken for 1 epoch 12.561168432235718 sec
#
# Epoch 88 Batch 0 Loss 0.0127
# Epoch 88 Loss 0.0148
# Time taken for 1 epoch 13.560943126678467 sec
#
# Epoch 89 Batch 0 Loss 0.0162
# Epoch 89 Loss 0.0139
# Time taken for 1 epoch 12.56684160232544 sec
#
# Epoch 90 Batch 0 Loss 0.0098
# Epoch 90 Loss 0.0130
# Time taken for 1 epoch 13.692833185195923 sec
#
# Epoch 91 Batch 0 Loss 0.0070
# Epoch 91 Loss 0.0118
# Time taken for 1 epoch 12.562097787857056 sec
#
# Epoch 92 Batch 0 Loss 0.0122
# Epoch 92 Loss 0.0112
# Time taken for 1 epoch 13.603990077972412 sec
#
# Epoch 93 Batch 0 Loss 0.0105
# Epoch 93 Loss 0.0112
# Time taken for 1 epoch 12.587066650390625 sec
#
# Epoch 94 Batch 0 Loss 0.0077
# Epoch 94 Loss 0.0107
# Time taken for 1 epoch 13.739520072937012 sec
#
# Epoch 95 Batch 0 Loss 0.0109
# Epoch 95 Loss 0.0100
# Time taken for 1 epoch 12.595166444778442 sec
#
# Epoch 96 Batch 0 Loss 0.0125
# Epoch 96 Loss 0.0100
# Time taken for 1 epoch 13.63123369216919 sec
#
# Epoch 97 Batch 0 Loss 0.0059
# Epoch 97 Loss 0.0089
# Time taken for 1 epoch 12.571027040481567 sec
#
# Epoch 98 Batch 0 Loss 0.0071
# Epoch 98 Loss 0.0087
# Time taken for 1 epoch 13.611937999725342 sec
#
# Epoch 99 Batch 0 Loss 0.0052
# Epoch 99 Loss 0.0088
# Time taken for 1 epoch 12.544809818267822 sec
#
# Epoch 100 Batch 0 Loss 0.0061
# Epoch 100 Loss 0.0091
# Time taken for 1 epoch 13.644100666046143 sec

# %%
# restoring the latest checkpoint in checkpoint_dir
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
def evaluate(sentence):
  attention_plot = np.zeros((max_length_targ, max_length_inp))

  sentence = preprocess_sentence(sentence)

  inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
  inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs], 
                                                         maxlen=max_length_inp, 
                                                         padding='post')

  inputs = tf.convert_to_tensor(inputs)

  result = ''

  hidden = [tf.zeros((1, units))]
  enc_out, enc_hidden = encoder(inputs, hidden)

  dec_hidden = enc_hidden
  dec_input = tf.expand_dims([targ_lang.word_index['<start>']], 0)

  for t in range(max_length_targ):
    predictions, dec_hidden, attention_weights = decoder(dec_input,
                                                         dec_hidden,
                                                         enc_out)

    # storing the attention weights to plot later on
    attention_weights = tf.reshape(attention_weights, (-1, ))
    attention_plot[t] = attention_weights.numpy()

    predicted_id = tf.argmax(predictions[0]).numpy()

    result += targ_lang.index_word[predicted_id] + ' '

    if targ_lang.index_word[predicted_id] == '<end>':
      return result, sentence, attention_plot

    # the predicted ID is fed back into the model
    dec_input = tf.expand_dims([predicted_id], 0)

  return result, sentence, attention_plot

# %%
# function for plotting the attention weights
def plot_attention(attention, sentence, predicted_sentence):
  fig = plt.figure(figsize=(10,10))
  ax = fig.add_subplot(1, 1, 1)
  ax.matshow(attention, cmap='viridis')

  fontdict = {'fontsize': 14}

  ax.set_xticklabels([''] + sentence, fontdict=fontdict, rotation=90)
  ax.set_yticklabels([''] + predicted_sentence, fontdict=fontdict)

  ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
  ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

  plt.show()

# %%
def translate(sentence):
  result, sentence, attention_plot = evaluate(sentence)

  print('Input: %s' % (sentence))
  print('Predicted translation: {}'.format(result))

  attention_plot = attention_plot[:len(result.split(' ')), :len(sentence.split(' '))]
  plot_attention(attention_plot, sentence.split(' '), result.split(' '))

  return result

# %%
# # restoring the latest checkpoint in checkpoint_dir
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
result = translate(u'Renang olahraga yang menyehatkan dan memiliki manfaat bagi tubuh')
# Out:
# Input: <start> renang olahraga yang menyehatkan dan memiliki manfaat bagi tubuh <end>
# Predicted translation: swimming sports are healthy and have benefits for the body <end>
